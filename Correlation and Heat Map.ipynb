# %%
import pandas as pd
Cleaned=pd.read_csv('Cleaned.csv')

# %%
Cleaned.head()
# Out:
#    Unnamed: 0                   lei  derived_msa_md state_code  county_code  \
# 0         549  549300LBCBNR1OT00651           41180         MO        29099
# 1         550  549300LBCBNR1OT00651           41180         MO        29099
# 2         551  549300LBCBNR1OT00651           41180         MO        29189
# 3         552  549300LBCBNR1OT00651           41180         MO        29099
# 4         553  549300LBCBNR1OT00651           28140         MO        29047
#
#    census_tract derived_loan_product_type  \
# 0   29099700109            FHA:First Lien
# 1   29099700502        FSA/RHS:First Lien
# 2   29189210927             VA:First Lien
# 3   29099701000        FSA/RHS:First Lien
# 4   29047021208            FHA:First Lien
#
#               derived_dwelling_category       derived_ethnicity  \
# 0  Single Family (1-4 Units):Site-Built  Not Hispanic or Latino
# 1  Single Family (1-4 Units):Site-Built  Not Hispanic or Latino
# ...

# %%
Cleaned.tail()
# Out:
#       Unnamed: 0                   lei  derived_msa_md state_code  \
# 8109       14100  549300FGXN1K3HLB1R50           17860         MO
# 8110       14103  549300FGXN1K3HLB1R50           28140         MO
# 8111       14104  549300FGXN1K3HLB1R50           99999         MO
# 8112       14107  549300FGXN1K3HLB1R50           41180         MO
# 8113       14108  549300FGXN1K3HLB1R50           99999         MO
#
#       county_code  census_tract derived_loan_product_type  \
# 8109        29019   29019001902   Conventional:First Lien
# 8110        29095   29095014905   Conventional:First Lien
# 8111        29007   29007950600   Conventional:First Lien
# 8112        29099   29099700603             VA:First Lien
# 8113        29209   29209090601   Conventional:First Lien
#
#                  derived_dwelling_category       derived_ethnicity  \
# 8109  Single Family (1-4 Units):Site-Built  Not Hispanic or Latino
# 8110  Single Family (1-4 Units):Site-Built  Not Hispanic or Latino
# ...

# %%
Cleaned.describe()
# Out:
#          Unnamed: 0  derived_msa_md   county_code  census_tract  action_taken  \
# count   8114.000000     8114.000000   8114.000000  8.114000e+03   8114.000000
# mean    7865.562731    50212.951812  29127.129652  2.912745e+10      1.572714
# std     3664.092549    27897.360855     88.688484  8.868184e+07      1.029432
# min      549.000000    16020.000000  29001.000000  2.900195e+10      1.000000
# 25%     4711.250000    28140.000000  29069.000000  2.906936e+10      1.000000
# 50%     7933.000000    41180.000000  29099.000000  2.909970e+10      1.000000
# 75%    11058.750000    44180.000000  29183.000000  2.918331e+10      2.000000
# max    14108.000000    99999.000000  29510.000000  2.951013e+10      5.000000
#
#        purchaser_type  preapproval    loan_type  loan_purpose  lien_status  \
# count     8114.000000  8114.000000  8114.000000   8114.000000  8114.000000
# mean         1.447745     1.956618     1.438008     25.027853     1.000123
# ...

# %%
corelation = Cleaned.corr()

# %%
import seaborn as sn
import matplotlib.pyplot as plt
data = Cleaned
df = pd.DataFrame(data)
corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=False)
plt.show()

# %%
Cleaned.groupby(['applicant_ethnicity_1', 'origination_charges']).mean()
# Out:
#                                              Unnamed: 0  derived_msa_md  \
# applicant_ethnicity_1 origination_charges
# 1                     0.00                 10391.444444    42253.222222
#                       250.00                8226.000000    28140.000000
#                       320.63                1623.000000    41180.000000
#                       753.00                3884.000000    41180.000000
#                       1047.70               2084.000000    99999.000000
# ...                                                 ...             ...
# 14                    4703.08              13382.000000    99999.000000
#                       4990.45              10172.000000    28140.000000
#                       5480.00              11692.000000    99999.000000
#                       5529.13               2615.000000    28140.000000
#                       6072.15              11993.000000    41180.000000
#
# ...

# %%
print("Correlation Matrix")
print(Cleaned.corr())
print()
def get_redundant_pairs(Cleaned):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = Cleaned.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop
def get_top_abs_correlations(Cleaned, n=5):
    au_corr = Cleaned.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
print(get_top_abs_correlations(Cleaned, 3))
# Out:
# Correlation Matrix
#                                           Unnamed: 0  derived_msa_md  \
# Unnamed: 0                                  1.000000       -0.040533
# derived_msa_md                             -0.040533        1.000000
# county_code                                 0.021770        0.080733
# census_tract                                0.021655        0.083024
# action_taken                               -0.079680        0.030694
# purchaser_type                              0.058763       -0.042732
# preapproval                                 0.060903        0.005838
# loan_type                                  -0.165995        0.128311
# loan_purpose                                0.094364       -0.084460
# lien_status                                 0.017889       -0.003595
# reverse_mortgage                                 NaN             NaN
# open_end_line_of_credit                    -0.014265        0.009787
# ...
