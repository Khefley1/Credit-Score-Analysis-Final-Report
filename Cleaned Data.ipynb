# %%
import pandas as pd
df=pd.read_csv('Cleaned.csv')
df.shape
# Out:
# (8114, 30)

# %%
df.isna().sum()
# Out:
# App ID                               0
# state_code                           0
# county_code                          0
# derived_loan_product_type            0
# derived_dwelling_category            0
# derived_race                         0
# derived_sex                          0
# action_taken                         0
# purchaser_type                       0
# preapproval                          0
# loan_type                            0
# loan_purpose                         0
# lien_status                          0
# business_or_commercial_purpose       0
# loan_amount                          0
# combined_loan_to_value_ratio      1388
# interest_rate                     1898
# rate_spread                       1899
# hoepa_status                         0
# total_loan_costs                  2055
# total_points_and_fees             8114
# origination_charges               2055
# discount_points                   3236
# lender_credits                    8092
# ...

# %%
df = df.drop(columns = ['lender_credits', 'total_points_and_fees', 'rate_spread', 'discount_points'])

# %%
df = df.dropna()
df.head()
# Out:
#     App ID state_code  county_code derived_loan_product_type  \
# 6      558         MO        29097            FHA:First Lien
# 16     568         MO        29189            FHA:First Lien
# 18     570         MO        29183            FHA:First Lien
# 32     766         MO        29077            FHA:First Lien
# 33     768         MO        29161             VA:First Lien
#
#                derived_dwelling_category               derived_race  \
# 6   Single Family (1-4 Units):Site-Built                      White
# 16  Single Family (1-4 Units):Site-Built  Black or African American
# 18  Single Family (1-4 Units):Site-Built  Black or African American
# 32  Single Family (1-4 Units):Site-Built                      White
# 33  Single Family (1-4 Units):Site-Built                      White
#
#    derived_sex  action_taken  purchaser_type  preapproval  ...  interest_rate  \
# 6         Male             1               9            2  ...          3.625
# ...

# %%
data = Biases.copy()                               # Create duplicate of data
data = data.replace(r'^s*$', float('NaN'), regex = True)  # Replace blanks by NaN
print(data)
# Out:
#       App ID state_code  county_code derived_loan_product_type  \
# 0        549         MO        29099            FHA:First Lien
# 1        550         MO        29099        FSA/RHS:First Lien
# 2        551         MO        29189             VA:First Lien
# 3        552         MO        29099        FSA/RHS:First Lien
# 4        553         MO        29047            FHA:First Lien
# ...      ...        ...          ...                       ...
# 8109   14100         MO        29019   Conventional:First Lien
# 8110   14103         MO        29095   Conventional:First Lien
# 8111   14104         MO        29007   Conventional:First Lien
# 8112   14107         MO        29099             VA:First Lien
# 8113   14108         MO        29209   Conventional:First Lien
#
#                  derived_dwelling_category               derived_race  \
# 0     Single Family (1-4 Units):Site-Built                      White
# ...

# %%
data = data.dropna()
print (data)
# Out:
# Empty DataFrame
# Columns: [App ID, state_code, county_code, derived_loan_product_type, derived_dwelling_category, derived_race, derived_sex, action_taken, purchaser_type, preapproval, loan_type, loan_purpose, lien_status, business_or_commercial_purpose, loan_amount, combined_loan_to_value_ratio, interest_rate, rate_spread, hoepa_status, total_loan_costs, total_points_and_fees, origination_charges, discount_points, lender_credits, property_value, occupancy_type, income, debt_to_income_ratio, applicant_credit_score_type, applicant_ethnicity_1]
# Index: []
#
# [0 rows x 30 columns]

# %%
data2.to_csv('cleaned-final.csv')
