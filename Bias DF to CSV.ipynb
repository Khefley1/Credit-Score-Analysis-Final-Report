# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Mo Mortgage.csv')
df.head()
# Out:
#    activity_year                   lei  derived_msa_md state_code  \
# 0           2020  549300LBCBNR1OT00651           28140         MO
# 1           2020  549300LBCBNR1OT00651           41180         MO
# 2           2020  549300LBCBNR1OT00651           41180         MO
# 3           2020  549300LBCBNR1OT00651           41180         MO
# 4           2020  549300LBCBNR1OT00651           41180         MO
#
#    county_code  census_tract conforming_loan_limit derived_loan_product_type  \
# 0        29095   29095013902                     C            FHA:First Lien
# 1        29189   29189219400                     C            FHA:First Lien
# 2        29189   29189211331                     C            FHA:First Lien
# 3        29183   29183312001                     C   Conventional:First Lien
# 4        29183   29183312097                     C            FHA:First Lien
#
#               derived_dwelling_category        derived_ethnicity  ...  \
# ...

# %%
to_drop = ['conforming_loan_limit',
          'activity_year']

df.drop(to_drop, inplace=True, axis=1)

# %%
df = df[~df["derived_ethnicity"].isin(["Ethnicity Not Available"])]

# %%
df = df[~df["derived_race"].isin(["Race Not Available"])]

# %%
df = df[~df["derived_sex"].isin(["Sex Not Available"])]

# %%
df.to_csv(r'C:\Users\Kyle\OneDrive\Documents\GitHub\loanBiases\Cleaned.csv')
